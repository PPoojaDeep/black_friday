# %% [markdown]
# # TASK 2.2 (Exploratory Data Analysis)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv("user_demographics.csv")
data1
# Out:
#       User_ID Gender    Age  Occupation
# 0     1000001      F   0-17          10
# 1     1000002      M    55+          16
# 2     1000003      M  26-35          15
# 3     1000004      M  46-50           7
# 4     1000005      M  26-35          20
# ...       ...    ...    ...         ...
# 5886  1004588      F  26-35           4
# 5887  1004871      M  18-25          12
# 5888  1004113      M  36-45          17
# 5889  1005391      M  26-35           7
# 5890  1001529      M  18-25           4
#
# [5891 rows x 4 columns]

# %%
data2=pd.read_csv("User_product_purchase_details_p2.csv")
data2
# Out:
#         User_ID Product_ID City_Category Stay_In_Current_City_Years  \
# 0       1000001  P00069042             A                          2
# 1       1000001  P00248942             A                          2
# 2       1000001  P00087842             A                          2
# 3       1000001  P00085442             A                          2
# 4       1000002  P00285442             C                         4+
# ...         ...        ...           ...                        ...
# 550063  1006033  P00372445             B                          1
# 550064  1006035  P00375436             C                          3
# 550065  1006036  P00375436             B                         4+
# 550066  1006038  P00375436             C                          2
# 550067  1006039  P00371644             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 0                    0                   3                 NaN
# ...

# %%
data=pd.merge(data1,data2,on='User_ID',how='right')
data.head(20)
# Out:
#     User_ID Gender    Age  Occupation Product_ID City_Category  \
# 0   1000001      F   0-17          10  P00069042             A
# 1   1000001      F   0-17          10  P00248942             A
# 2   1000001      F   0-17          10  P00087842             A
# 3   1000001      F   0-17          10  P00085442             A
# 4   1000002      M    55+          16  P00285442             C
# 5   1000003      M  26-35          15  P00193542             A
# 6   1000004      M  46-50           7  P00184942             B
# 7   1000004      M  46-50           7  P00346142             B
# 8   1000004      M  46-50           7   P0097242             B
# 9   1000005      M  26-35          20  P00274942             A
# 10  1000005      M  26-35          20  P00251242             A
# 11  1000005      M  26-35          20  P00014542             A
# 12  1000005      M  26-35          20  P00031342             A
# 13  1000005      M  26-35          20  P00145042             A
# ...

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#         User_ID Gender    Age  Occupation Product_ID City_Category  \
# 0       1000001      F   0-17          10  P00069042             A
# 1       1000001      F   0-17          10  P00248942             A
# 2       1000001      F   0-17          10  P00087842             A
# 3       1000001      F   0-17          10  P00085442             A
# 4       1000002      M    55+          16  P00285442             C
# ...         ...    ...    ...         ...        ...           ...
# 550063  1006033      M  51-55          13  P00372445             B
# 550064  1006035      F  26-35           1  P00375436             C
# 550065  1006036      F  26-35          15  P00375436             B
# 550066  1006038      F    55+           1  P00375436             C
# 550067  1006039      F  46-50           0  P00371644             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# ## Basic data exploration
# ### to check what the dataset comprises of
# * head of the dataset
# * shape of the dataset
# * info of the dataset
# * summary of the dataset

# %%
df.head(10).T
# Out:
#                                     0          1          2          3  \
# User_ID                       1000001    1000001    1000001    1000001
# Gender                              F          F          F          F
# Age                              0-17       0-17       0-17       0-17
# Occupation                         10         10         10         10
# Product_ID                  P00069042  P00248942  P00087842  P00085442
# City_Category                       A          A          A          A
# Stay_In_Current_City_Years          2          2          2          2
# Marital_Status                      0          0          0          0
# Product_Category_1                  3          1         12         12
# Product_Category_2                NaN        6.0        NaN       14.0
# Product_Category_3                NaN       14.0        NaN        NaN
# Purchase                         8370      15200       1422       1057
#
# ...

# %% [markdown]
# head function will tell you the top records in the data sets. By default python will show you only the first five records.

# %%
df.shape
# Out:
# (550068, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Gender                      550068 non-null  object
#  2   Age                         550068 non-null  object
#  3   Occupation                  550068 non-null  int64
#  4   Product_ID                  550068 non-null  object
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %% [markdown]
# info() is used to check tha information about the data and datatype of each respective attributes.

# %%
df.describe().T
# Out:
#                        count          mean          std        min        25%  \
# User_ID             550068.0  1.003029e+06  1727.591586  1000001.0  1001516.0
# Occupation          550068.0  8.076707e+00     6.522660        0.0        2.0
# Marital_Status      550068.0  4.096530e-01     0.491770        0.0        0.0
# Product_Category_1  550068.0  5.404270e+00     3.936211        1.0        1.0
# Product_Category_2  376430.0  9.842329e+00     5.086590        2.0        5.0
# Product_Category_3  166821.0  1.266824e+01     4.125338        3.0        9.0
# Purchase            550068.0  9.263969e+03  5023.065394       12.0     5823.0
#
#                           50%        75%        max
# User_ID             1003077.0  1004478.0  1006040.0
# Occupation                7.0       14.0       20.0
# Marital_Status            0.0        1.0        1.0
# Product_Category_1        5.0        8.0       20.0
# Product_Category_2        9.0       15.0       18.0
# ...

# %% [markdown]
# we can get a sense of outliers-extreme values,skewness.
#
# how the data has been spread- distribution of the numerical,min,max, diiferent percentiles.
#
# max contains extreme values on the right.
#
# min contains extreme values on the left.

# %% [markdown]
# #### check for duplicate records

# %%
dups=df.duplicated()
dups.sum()
# Out:
# 0

# %% [markdown]
# we don't have any duplicate values in our dataset.

# %% [markdown]
# #### ●	Missing values identification and treatment

# %% [markdown]
# * if data is not missing at random you are going to domain expertise to understand what to do with it.
#
# * undersatnd the typology of missing data(random/ not random pattern)
#
# * dropping data missing not at random is dangerous.
#
# * result in significant bias in our model.

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Gender                             0
# Age                                0
# Occupation                         0
# Product_ID                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
data.isnull().sum()*100/len(data)
# Out:
# User_ID                        0.000000
# Gender                         0.000000
# Age                            0.000000
# Occupation                     0.000000
# Product_ID                     0.000000
# City_Category                  0.000000
# Stay_In_Current_City_Years     0.000000
# Marital_Status                 0.000000
# Product_Category_1             0.000000
# Product_Category_2            31.566643
# Product_Category_3            69.672659
# Purchase                       0.000000
# dtype: float64

# %% [markdown]
# * A feature that has a high number of empty values is unlikely to be very useful for prediction. It can be safely dropped.

# %% [markdown]
# * Dropping Productcategory3 as they have missing values more than 50% and imputing Product Category 2 with mode

# %% [markdown]
# #### ways of treating your missing values in the dataset
# * Drop the missing value - last resort/ very few missing values
# * impute with mean value   - Numerical value
# * impute with median value - Numerical value
# * impute with median value - Categorical value

# %%
df[df.isnull().sum()[df.isnull().sum()>0].index].dtypes
# Out:
# Product_Category_2    float64
# Product_Category_3    float64
# dtype: object

# %%
#df['Product_Category_2'].replace(np.nan,df['Product_Category_2'].median,inplace=True)
#df['Product_Category_3'].replace(np.nan,df['Product_Category_3'].median,inplace=True)
#df.drop(columns=['Product_Category_3'], axis=1 ,inplace = True)

# %%
df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0],inplace = True)
df.drop(columns=['Product_Category_3'], axis=1 ,inplace = True)

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Gender                        0
# Age                           0
# Occupation                    0
# Product_ID                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# #### ● Univariate, Bi- Variate Analysis and Multi- Variate Analysis

# %% [markdown]
# * Univariate Analysis

# %%
plt.figure(figsize=(12,7))
sns.distplot(df.Purchase,bins = 25)
plt.xlabel("Amount spent in Purchase"),
plt.ylabel("Number of Buyers")
plt.title("Purchase amount Distribution")
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Purchase amount Distribution')

# %%
print(df.Purchase.skew())
print(df.Purchase.kurt())
# Out:
# 0.6001400037087128
# -0.3383775655851702

# %%
sns.set_style('whitegrid')
df.drop('User_ID',axis=1).hist(figsize=(13,10),color='lightblue')
plt.tight_layout()

# %% [markdown]
# on numerical data

# %%
num = df.select_dtypes(include=[np.number])
num.dtypes
# Out:
# User_ID                 int64
# Occupation              int64
# Marital_Status          int64
# Product_Category_1      int64
# Product_Category_2    float64
# Purchase                int64
# dtype: object

# %% [markdown]
# Distribution of the Occupation variable

# %%
sns.countplot(df.Occupation);
plt.title('count of occupation');
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.Marital_Status);
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.Product_Category_1);
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.Product_Category_2)
plt.xticks(rotation=90);
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
corr = num.corr()

corr['Purchase'].sort_values(ascending=False)[:10]
# Out:
# Purchase              1.000000
# Occupation            0.020833
# User_ID               0.004716
# Marital_Status       -0.000463
# Product_Category_2   -0.128651
# Product_Category_1   -0.343703
# Name: Purchase, dtype: float64

# %%
f, ax = plt.subplots(figsize=(20, 9))
sns.heatmap(corr, vmax=.8,annot_kws={'size': 20}, annot=True);

# %% [markdown]
# on categorical data

# %%
sns.countplot(df.Gender);
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.Age);
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.City_Category);
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.Stay_In_Current_City_Years);
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df['City_Category'],hue=df['Gender'])
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(df['Stay_In_Current_City_Years'],hue=df['Gender'])
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(df['Occupation'],hue=df['Stay_In_Current_City_Years'])
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.set_style('whitegrid')
sns.distplot(df['Purchase'],kde=False,bins=30)
plt.show()
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * Bivariate Analysis

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="Occupation", y="Purchase", data=df)
plt.title('Occupation and Purchase')
# Out:
# Text(0.5, 1.0, 'Occupation and Purchase')

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="Marital_Status", y="Purchase", data=df)
plt.title('Marital_Status and Purchase');

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="Product_Category_1", y="Purchase", data=df)
plt.title('Product_Category_1 and Purchase');

# %%
plt.figure(figsize=(10,5))
plot1 = sns.countplot(x="Product_Category_1", hue ='Marital_Status', data=df)
plt.title('Marital_Status and Product category 1');

# %%
plt.figure(figsize=(10,5))
plot = sns.countplot(x="Product_Category_1", hue ='Gender', data=df)
plt.title('Gender and product category 1');

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="Product_Category_2", y ='Purchase', data=df)
plt.title('Gender and product category 2');

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="Gender", y ='Purchase', data=df)
plt.title('Gender and Purchase');

# %%
Product_category_1_pivot = df.pivot_table(index='Age', values="Purchase", aggfunc=np.sum)
Product_category_1_pivot.plot(kind='bar', figsize=(12,7))
plt.xlabel("Age")
plt.ylabel("Purchase")
plt.title("Age and Purchase Analysis")
plt.xticks(rotation=0)

plt.show()

# %%
plt.figure(figsize=(12,10))
sns.barplot(x="Age", y ='Purchase', data=df)
plt.title('Age and Purchase');

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="City_Category", y ='Purchase', data=df)
plt.title('City Category and Purchase');

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="Stay_In_Current_City_Years", y ='Purchase', data=df)
plt.title('Stay_In_Current_City_Years and Purchase');

# %%
plt.figure(figsize = (20,8))
sns.barplot(x='City_Category', y='Purchase',hue = 'Age',data = df)
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Purchase'>

# %% [markdown]
# #### ●	Outlier analysis and treatment

# %%
df.boxplot(column=['Occupation'], showmeans=True)
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['Product_Category_1'], showmeans=True)
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['Product_Category_2'], showmeans=True)
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['Purchase'], showmeans=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Product_category, purchase columns have ouliers present in data
#
# this outliers need to treated
# * Drop the outliers
# * Replace the outlier value using the IQR

# %%
def remove_outlier(col):
    Q1,Q3=col.sort_values().quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range=Q1-(1.5*IQR)
    upper_range=Q3+(1.5*IQR)
    return lower_range, upper_range

# %%
lr,ur=remove_outlier(df['Product_Category_1'])
df['Product_Category_1']=np.where(df['Product_Category_1']>ur,ur,df['Product_Category_1'])
df['Product_Category_1']=np.where(df['Product_Category_1']<lr,lr,df['Product_Category_1'])

plr,pur=remove_outlier(df['Purchase'])
df['Purchase']=np.where(df['Purchase']>pur,pur,df['Purchase'])
df['Purchase']=np.where(df['Purchase']<plr,plr,df['Purchase'])

# %%
df.boxplot(column=['Product_Category_1'], showmeans=True)
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['Purchase'], showmeans=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### ● Data scaling using min-max and/or  Z-score normalisation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 550068 entries, 0 to 550067
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Gender                      550068 non-null  object
#  2   Age                         550068 non-null  object
#  3   Occupation                  550068 non-null  int64
#  4   Product_ID                  550068 non-null  object
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  float64
#  9   Product_Category_2          550068 non-null  float64
#  10  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 66.5+ MB

# %% [markdown]
# min-max

# %%
from sklearn.preprocessing import StandardScaler
std_scale=StandardScaler()

df['Occupation']=std_scale.fit_transform(df[['Occupation']])
df['Purchase']=std_scale.fit_transform(df[['Purchase']])

# %%
df.head()
# Out:
#    User_ID Gender   Age  Occupation Product_ID City_Category  \
# 0  1000001      F  0-17    0.294864  P00069042             A
# 1  1000001      F  0-17    0.294864  P00248942             A
# 2  1000001      F  0-17    0.294864  P00087842             A
# 3  1000001      F  0-17    0.294864  P00085442             A
# 4  1000002      M   55+    1.214734  P00285442             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                 3.0
# 1                          2               0                 1.0
# 2                          2               0                12.0
# 3                          2               0                12.0
# 4                         4+               0                 8.0
#
#    Product_Category_2  Purchase
# 0                 8.0 -0.177022
# 1                 6.0  1.189111
# 2                 8.0 -1.566758
# 3                14.0 -1.639765
# 4                 8.0 -0.257230

# %%
sns.distplot(df['Purchase'])
# Out:
# C:\Users\ppoojadeep\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Purchase', ylabel='Density'>

# %% [markdown]
# #### ●	Data transformation

# %%
gender = np.unique(df['Gender'])
gender

def map_gender(gender):
    if gender == 'M':
        return 1
    else:
        return 0
    
df['Gender'] = df['Gender'].apply(map_gender)

df["Gender"].value_counts()
# Out:
# 1    414259
# 0    135809
# Name: Gender, dtype: int64

# %%
age_dict = {'0-17':1, '18-25':2, '26-35':3, '36-45':4, '46-50':5, '51-55':6, '55+':7}
df["Age"] = df["Age"].apply(lambda line: age_dict[line])

df["Age"].value_counts()
# Out:
# 3    219587
# 4    110013
# 2     99660
# 5     45701
# 6     38501
# 7     21504
# 1     15102
# Name: Age, dtype: int64

# %%
city_dict = {'A':1, 'B':2, 'C':3}
df["City_Category"] = df["City_Category"].apply(lambda line: city_dict[line])

df["City_Category"].value_counts()
# Out:
# 2    231173
# 3    171175
# 1    147720
# Name: City_Category, dtype: int64

# %%
def map_stay(stay):
        if stay == '4+':
            return 4
        else:
            return int(stay)
df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].apply(map_stay)

df.Stay_In_Current_City_Years.head(5)
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    4
# Name: Stay_In_Current_City_Years, dtype: int64

# %%
df
# Out:
#         User_ID  Gender  Age  Occupation Product_ID  City_Category  \
# 0       1000001       0    1    0.294864  P00069042              1
# 1       1000001       0    1    0.294864  P00248942              1
# 2       1000001       0    1    0.294864  P00087842              1
# 3       1000001       0    1    0.294864  P00085442              1
# 4       1000002       1    7    1.214734  P00285442              3
# ...         ...     ...  ...         ...        ...            ...
# 550063  1006033       1    6    0.754799  P00372445              2
# 550064  1006035       0    3   -1.084943  P00375436              3
# 550065  1006036       0    3    1.061423  P00375436              2
# 550066  1006038       0    7   -1.084943  P00375436              3
# 550067  1006039       0    5   -1.238255  P00371644              2
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                 3.0
# ...

# %%
df_final = df.drop(["User_ID","Product_ID"], axis=1)
df_final.head(5)
# Out:
#    Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0       0    1    0.294864              1                           2
# 1       0    1    0.294864              1                           2
# 2       0    1    0.294864              1                           2
# 3       0    1    0.294864              1                           2
# 4       1    7    1.214734              3                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Purchase
# 0               0                 3.0                 8.0 -0.177022
# 1               0                 1.0                 6.0  1.189111
# 2               0                12.0                 8.0 -1.566758
# 3               0                12.0                14.0 -1.639765
# 4               0                 8.0                 8.0 -0.257230

# %%
x = df_final.drop("Purchase", axis=1)  #independent columns
y = df_final["Purchase"]

# %%
x
# Out:
#         Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0            0    1    0.294864              1                           2
# 1            0    1    0.294864              1                           2
# 2            0    1    0.294864              1                           2
# 3            0    1    0.294864              1                           2
# 4            1    7    1.214734              3                           4
# ...        ...  ...         ...            ...                         ...
# 550063       1    6    0.754799              2                           1
# 550064       0    3   -1.084943              3                           3
# 550065       0    3    1.061423              2                           4
# 550066       0    7   -1.084943              3                           2
# 550067       0    5   -1.238255              2                           4
#
#         Marital_Status  Product_Category_1  Product_Category_2
# ...

# %% [markdown]
# #### ●	Feature Engineering

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_regression

# %%
bestfeatures = SelectKBest(score_func=f_regression , k=8)
fit = bestfeatures.fit(x,y)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)

# %%
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score']

# %%
featureScores.nlargest(8,"Score")
# Out:
#                      Features         Score
# 6          Product_Category_1  74899.458480
# 7          Product_Category_2   9620.018883
# 3               City_Category   2127.599042
# 0                      Gender   2024.613161
# 2                  Occupation    239.304847
# 1                         Age    129.951120
# 4  Stay_In_Current_City_Years     16.463579
# 5              Marital_Status      0.197209

# %%
final= df_final.drop(["Marital_Status","Stay_In_Current_City_Years"],axis=1)
final.head(), final.shape
# Out:
# (   Gender  Age  Occupation  City_Category  Product_Category_1  \
#  0       0    1    0.294864              1                 3.0
#  1       0    1    0.294864              1                 1.0
#  2       0    1    0.294864              1                12.0
#  3       0    1    0.294864              1                12.0
#  4       1    7    1.214734              3                 8.0
#
#     Product_Category_2  Purchase
#  0                 8.0 -0.177022
#  1                 6.0  1.189111
#  2                 8.0 -1.566758
#  3                14.0 -1.639765
#  4                 8.0 -0.257230  ,
#  (550068, 7))

# %% [markdown]
# # Task 2.4(Model building using ML algorithms)

# %%
# Lets Build a Model using the top 6 best features
x = final.drop("Purchase",axis=1)
y = final["Purchase"]

np.random.seed(42)
# Lets Divide the Data in Train and Test Set
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn import metrics

LR = LinearRegression()
LR.fit(x_train,y_train)
y_pred = LR.predict(x_test)


R2Linear = r2_score(y_test, y_pred)
MAELinear = mean_absolute_error(y_test,y_pred)
RMSELinear= np.sqrt(metrics.mean_squared_error(y_test, y_pred))

print('R2 score for linear model: ', R2Linear)
print('Mean Absolute error: ', MAELinear)
print('RMSE:', RMSELinear)
# Out:
# R2 score for linear model:  0.12647574139551465
# Mean Absolute error:  0.7162738492271402
# RMSE: 0.9328612098444706

# %%
from sklearn.tree import DecisionTreeRegressor


DT = DecisionTreeRegressor(max_depth=15, min_samples_leaf=100)
DT.fit(x_train,y_train)
y_pred = DT.predict(x_test)

R2DecisionT = r2_score(y_test, y_pred)
MAEDecisionT = mean_absolute_error(y_test,y_pred)
RMSEDecisionT= np.sqrt(metrics.mean_squared_error(y_test, y_pred))


print('R2 score for DecisionTree model: ', R2DecisionT)
print('Mean Absolute error: ', MAEDecisionT)
print('RMSE:', RMSEDecisionT)
# Out:
# R2 score for DecisionTree model:  0.6410564891154767
# Mean Absolute error:  0.44734971688675085
# RMSE: 0.5979881841826153

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators = 100, min_samples_split=5 ,max_features='sqrt', random_state =0)
rf.fit(x_train,y_train)
y_pred= rf.predict(x_test)


R2RandomF = r2_score(y_test, y_pred)
MAERandomF = mean_absolute_error(y_test,y_pred)
RMSERandomF= np.sqrt(metrics.mean_squared_error(y_test, y_pred))


print('R2 score for RandomForestRegression model: ', R2RandomF)
print('Mean Absolute error: ', MAERandomF)
print('RMSE:', RMSERandomF)
# Out:
# R2 score for RandomForestRegression model:  0.6366687398583437
# Mean Absolute error:  0.4476247766846333
# RMSE: 0.6016320060169785

# %%
import xgboost

xgb = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)
xgb.fit(x_train,y_train)
y_pred= xgb.predict(x_test)


R2xgb = r2_score(y_test, y_pred)
MAExgb = mean_absolute_error(y_test,y_pred)
RMSExgb= np.sqrt(metrics.mean_squared_error(y_test, y_pred))


print('R2 score for XGB model: ', R2xgb)
print('Mean Absolute error: ', MAExgb)
print('RMSE:', RMSExgb)
# Out:
# R2 score for XGB model:  0.6460161078721982
# Mean Absolute error:  0.44574034248534594
# RMSE: 0.593842532415997

# %%
from sklearn.model_selection import RandomizedSearchCV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 500, num = 5)]
# Number of features to consider at every split
max_features = ['sqrt','log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 100,3)]
# Minimum number of samples required to split a node
min_samples_split = [2,5,10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 8]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500], 'max_features': ['sqrt', 'log2'], 'max_depth': [10, 55, 100], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 8]}

# %%
XG= xgboost.XGBRegressor()
XG_randomcv=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,n_iter=10,cv=3,verbose=2,
                               random_state=100,n_jobs=-1)

### fit the randomized model
XG_randomcv.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3,
#                    estimator=RandomForestRegressor(max_features='sqrt',
#                                                    min_samples_split=5,
#                                                    random_state=0),
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [10, 55, 100],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 8],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500]},
#                    random_state=100, verbose=2)

# %%
best_xg = XG_randomcv.best_estimator_

# %%
y_pred= best_xg.predict(x_test)


R2randomCV = r2_score(y_test, y_pred)
MAErandomCV = mean_absolute_error(y_test,y_pred)
RMSErandomCV= np.sqrt(metrics.mean_squared_error(y_test, y_pred))


print('R2 score for DecisionTree with RandomisedSearchCV model: ', R2randomCV)
print('Mean Absolute error: ', MAErandomCV)
print('RMSE:', RMSErandomCV)
# Out:
# R2 score for DecisionTree with RandomisedSearchCV model:  0.6392797615189171
# Mean Absolute error:  0.4467637822631792
# RMSE: 0.5994663423827328

# %%
bestmodel_R2 =  {'Models':['Linear Regression Model',  'Decision Tree Model', 'RandomForest Regressor Model','XGB Model','XGBCV Model'], 'R2Scores':[R2Linear,R2DecisionT,R2RandomF,R2xgb,R2randomCV]}

# %%
bestmodel_R2
# Out:
# {'Models': ['Linear Regression Model',
#   'Decision Tree Model',
#   'RandomForest Regressor Model',
#   'XGB Model',
#   'XGBCV Model'],
#  'R2Scores': [0.12647574139551465,
#   0.6410564891154767,
#   0.6366687398583437,
#   0.6460161078721982,
#   0.6392797615189171]}

# %%
bestone= pd.DataFrame(bestmodel_R2) 
bestone
# Out:
#                          Models  R2Scores
# 0       Linear Regression Model  0.126476
# 1           Decision Tree Model  0.641056
# 2  RandomForest Regressor Model  0.636669
# 3                     XGB Model  0.646016
# 4                   XGBCV Model  0.639280

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="Models", y="R2Scores",data=bestone)
plt.title('best model')
# Out:
# Text(0.5, 1.0, 'best model')

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# We tried to build a model using various algorithms such as Linear regression, Decision tree regression, Random forest, GradientBoostingRegressor and XGB regressor to get the best possible prediction.
#
# The hyperparameter tuned XGB regressor gives us the best rmse value and r2 score for this problem.

# %%
import pickle

pickle.dump(xgb,open('Xgboost.pkl', 'wb'))
